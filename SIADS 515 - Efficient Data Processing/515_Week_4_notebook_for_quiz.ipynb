# %% [markdown]
# # SIADS 515 Week 4 Homework

# %% [markdown]
# ## Background
# This assignment uses is uses the same codebase as the previous one, however this
# assignment focuses on improving efficiency rather than fixing bugs.  Some of the background material is recreated below.
#
# The motivation for this assignment is to **improve the efficiency of code** that finds the similarity between any two given documents.  There are many ways to calculate similarity (or distance) between two documents, but the most effective way is to represent each document as a multi-dimensional vector where each dimension corresponds to a word, and the value along that dimension is the number of times that word occurs in a document.  Let's take a look at a simplified case where we only have two dimensions:
#
# ![](assets/CosineDistanceSimilarity.png)
#
# In the above diagram, Item 1 and Item 2 refer to two documents.  The angle between them (𝛳) can range from -180 to +180 degrees.  The cosine of angles, in this case, has a nice property in that the cosine of an angle of 0 degrees is 1, the cosine of an angle of 90 degrees is 0, and the cosine of an angle of 180 degrees is -1.  In other words, the cosine of the angle between the vector representation of a document behaves much like a correlation coefficient.  A cosine of 1 indicates the documents are identical, a cosine of 0 indicates the documents are independent of each other, and a cosine of -1 indicates the documents are "opposites" (note: the latter requires a specific setup that is beyond the scope of this course).
#
# Your task, for this assignment, is to improve the efficiency of the code.

# %%
# docdist1.py
# Original author: Ronald L. Rivest
# Some adaptation by Chris Teplovs and Kevyn Collins-Thompson
#
#
# This program computes the "distance" between two text files
# as the angle between their word frequency vectors.
#
# For each input file, a word-frequency vector is computed as follows:
#    (1) the specified file is read in
#    (2) it is converted into a list of alphanumeric "words"
#        Here a "word" is a sequence of consecutive alphanumeric
#        characters.  Non-alphanumeric characters are treated as blanks.
#        Case is not significant.
#    (3) for each word, its frequency of occurrence is determined
#    (4) the word/frequency lists are sorted into order alphabetically
#
# The "distance" between two vectors is the angle between them.
# If x = (x1, x2, ..., xn) is the first vector (xi = freq of word i)
# and y = (y1, y2, ..., yn) is the second vector,
# then the angle between them is defined as:
#    d(x,y) = arccos(inner_product(x,y) / (norm(x)*norm(y)))
# where:
#    inner_product(x,y) = x1*y1 + x2*y2 + ... xn*yn
#    norm(x) = sqrt(inner_product(x,x))

# %%
import math
    # math.acos(x) is the arccosine of x.
    # math.sqrt(x) is the square root of x.

import string
    # string.join(words,sep) takes a given list of words,
    #    and returns a single string resulting from concatenating them
    #    together, separated by the string sep .
    # string.lower(word) converts word to lower-case

import sys
    # sys.exit() allows us to quit (if we can't read a file)

# %%
##################################
# Operation 1: read a text file ##
##################################
def read_file(filename):
    ###    Read the text file with the given filename;
    ###     return a list of the lines of text in the file.
    try:
        fp = open(filename)
        L = fp.readlines()
    except IOError as excObj:
        print(str(excObj))
        print("Error opening or reading input file: " + filename)
        sys.exit()
    return L

# %%
len(read_file('assets/t8.shakespeare.txt'))
# Out:
# 124456

# %%
#################################################
# Operation 2: split the text lines into words ##
#################################################
def get_words_from_line_list(L):
    ### Parse the given list L of text lines into words.
    ### Return list of all words found.

    word_list = []
    for line in L:
        words_in_line = get_words_from_string(line)
        word_list = word_list + words_in_line
    return word_list

# %%
def get_words_from_string(line):
    ### Return a list of the words in the given input string,
    ### converting each word to lower-case.
    ###
    ### Input:  line (a string)
    ### Output: a list of strings
    ###          (each string is a sequence of alphanumeric characters)

    word_list = []          # accumulates words in line
    character_list = []     # accumulates characters in word
    for c in line:
        if c.isalnum():
            character_list.append(c)
        elif len(character_list)>0:
            word = str.join("", character_list)
            word = str.lower(word)
            word_list.append(word)
            character_list = []
    if len(character_list)>0:
        word = str.join("", character_list)
        word = str.lower(word)
        word_list.append(word)
    return word_list

# %%
##############################################
# Operation 3: count frequency of each word ##
##############################################
def count_frequency_original(word_list):
    ### Return a list giving pairs of form: (word,frequency)

    L = []
    for new_word in word_list:
        for entry in L:
            if new_word == entry[0]:
                entry[1] = entry[1] + 1
                break
        else:
            L.append([new_word,1])
    return L

# %%
##############################################
# Operation 3: count frequency of each word ## ********************* MODIFIED *********************
##############################################
def count_frequency(word_list):
    ### Return a list giving pairs of form: (word,frequency)

    freq_dict={}
    for word in word_list:
        if word in freq_dict:
            freq_dict[word]+=1
        else:
            freq_dict[word]=1
    
    L_tuples=list(zip(freq_dict.keys(), freq_dict.values()))
    L=[list(x) for x in L_tuples]
            
    return L

# %%
###############################################################
# Operation 4: sort words into alphabetic order             ###
###############################################################
def insertion_sort(A):

    ### Sort list A into order, in place.
    ###
    ### From Cormen/Leiserson/Rivest/Stein,
    ### Introduction to Algorithms (second edition), page 17,
    ### modified to adjust for fact that Python arrays use
    ### 0-indexing.

    for j in range(len(A)):
        key = A[j]
        # insert A[j] into sorted sequence A[0..j-1]
        i = j-1
        while i>-1 and A[i]>key:
            A[i+1] = A[i]
            i = i-1
        A[i+1] = key
    return A

# %%
#############################################
## compute word frequencies for input file ##
#############################################
def word_frequencies_for_file(filename,verbose=False):

    ### Return alphabetically sorted list of (word,frequency) pairs
    ### for the given file.

    line_list = read_file(filename)
    word_list = get_words_from_line_list(line_list)
    freq_mapping = count_frequency(word_list)
    insertion_sort(freq_mapping)
    if verbose:
        print("File",filename,":", len(line_list),"lines,", len(word_list),"words,", len(freq_mapping),"distinct words")

    return freq_mapping

# %%
# %load_ext line_profiler
# %lprun -f word_frequencies_for_file word_frequencies_for_file('assets/short.t1.txt')
# Out:
# The line_profiler extension is already loaded. To reload it, use:
#   %reload_ext line_profiler

# %%
def inner_product(L1,L2):

    ### Inner product between two vectors, where vectors
    ### are represented as alphabetically sorted (word,freq) pairs.

    ### Example: inner_product([["and",3],["of",2],["the",5]],
    ###                        [["and",4],["in",1],["of",1],["this",2]]) = 14.0

    sum = 0.0
    i = 0
    j = 0
    while i<len(L1) and j<len(L2):
        # L1[i:] and L2[j:] yet to be processed
        if L1[i][0] == L2[j][0]:
            # both vectors have this word
            sum += L1[i][1] * L2[j][1]
            i += 1
            j += 1
        elif L1[i][0] < L2[j][0]:
            # word L1[i][0] is in L1 but not L2
            i += 1
        else:
            # word L2[j][0] is in L2 but not L1
            j += 1
    return sum

# %%
def vector_angle(L1,L2):

    ### The input is a list of (word,freq) pairs, sorted alphabetically.
    ### Return the angle between these two vectors.

    numerator = inner_product(L1,L2)
    denominator = math.sqrt(inner_product(L1,L1)*inner_product(L2,L2))
    return numerator/denominator

# %%
def document_similarity(filename_1, filename_2, verbose=True):
    """DOCSTRING"""
    sorted_word_list_1 = word_frequencies_for_file(filename_1, verbose)
    sorted_word_list_2 = word_frequencies_for_file(filename_2, verbose)
    cosine = vector_angle(sorted_word_list_1,sorted_word_list_2)
    # Use f-strings; see https://realpython.com/python-f-strings/ for more information
    if verbose:
        print(f"The cosine between the documents is {cosine : 0.6f}.")
        print(f"The angle between the documents is {math.acos(cosine) : 0.6f} radians or {math.acos(cosine)*180/math.pi : .0f} degrees.")

# %%
document_similarity('assets/short.t1.txt','assets/short.t2.txt')
# Out:
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.

# %%
# %%timeit
document_similarity('assets/short.t1.txt','assets/short.t2.txt')
# Out:
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# 52.9 ms ± 246 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %timeit document_similarity('assets/short.t1.txt','assets/short.t2.txt')
# Out:
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.
# 53.1 ms ± 196 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# time with original code
# %timeit document_similarity('assets/t1.verne.txt','assets/t2.bobsey.txt')
# Out:
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# 2.67 s ± 11.7 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
document_similarity('assets/short.t1.txt','assets/short.t2.txt')
# Out:
# [['project', 3], ['gutenberg', 4], ['s', 10], ['in', 37], ['the', 137], ['year', 9], ['2889', 7], ['by', 13], ['jules', 4], ['verne', 7], ['and', 34], ['michel', 3], ['this', 13], ['ebook', 4], ['is', 33], ['for', 19], ['use', 2], ['of', 85], ['anyone', 1], ['anywhere', 1], ['at', 13], ['no', 3], ['cost', 2], ['with', 13], ['almost', 3], ['restrictions', 1], ['whatsoever', 1], ['you', 3], ['may', 3], ['copy', 1], ['it', 25], ['give', 2], ['away', 1], ['or', 7], ['re', 1], ['under', 4], ['terms', 1], ['license', 1], ['included', 1], ['online', 1], ['www', 1], ['org', 1], ['title', 1], ['author', 1], ['release', 1], ['date', 1], ['january', 1], ['2', 1], ['2007', 1], ['19362', 1], ['original', 1], ['version', 1], ['posted', 1], ['on', 6], ['september', 2], ['23', 1], ['2006', 1], ['language', 1], ['english', 1], ['character', 1], ['set', 2], ['encoding', 1], ['ascii', 1], ['start', 1], ['produced', 1], ['norm', 1], ['wolcott', 1], ['redactor', 1], ['note', 1], ['was', 17], ['first', 5], ['published', 3], ['forum', 1], ['february', 1], ['1889', 1], ['p', 1], ['262', 1], ['france', 2], ['next', 1], ['although', 1], ['name', 5], ['now', 6], ['believed', 1], ['to', 46], ['be', 8], ['chiefly', 1], ['if', 5], ['not', 8], ['entirely', 1], ['work', 3], ['son', 1], ['any', 3], ['event', 1], ['many', 2], ['topics', 1], ['article', 1], ['echo', 1], ['ideas', 1], ['little', 2], ['though', 3], ['they', 16], ['seem', 1], ['think', 3], ['people', 1], ['twenty', 2], ['ninth', 1], ['century', 1], ['live', 2], ['continually', 2], ['fairyland', 1], ['surfeited', 1], ['as', 9], ['are', 6], ['marvels', 1], ['indifferent', 1], ['presence', 1], ['each', 4], ['new', 3], ['marvel', 1], ['them', 3], ['all', 17], ['seems', 2], ['natural', 1], ['could', 4], ['but', 7], ['duly', 1], ['appreciate', 2], ['refinements', 1], ['civilization', 1], ['our', 8], ['day', 11], ['compare', 1], ['present', 2], ['past', 1], ['so', 3], ['better', 1], ['comprehend', 1], ['advance', 1], ['we', 4], ['have', 10], ['made', 3], ['how', 1], ['much', 1], ['fairer', 1], ['would', 6], ['find', 1], ['modern', 2], ['towns', 1], ['populations', 1], ['amounting', 1], ['sometimes', 1], ['10', 2], ['000', 7], ['souls', 1], ['their', 6], ['streets', 2], ['300', 1], ['feet', 3], ['wide', 1], ['houses', 1], ['1000', 2], ['height', 1], ['a', 29], ['temperature', 1], ['same', 4], ['seasons', 1], ['lines', 1], ['aerial', 2], ['locomotion', 1], ['crossing', 1], ['sky', 1], ['every', 4], ['direction', 1], ['picture', 1], ['themselves', 2], ['state', 1], ['things', 1], ['that', 20], ['once', 1], ['existed', 1], ['when', 5], ['through', 3], ['muddy', 1], ['rumbling', 1], ['boxes', 1], ['wheels', 1], ['drawn', 1], ['horses', 2], ['yes', 4], ['were', 4], ['only', 1], ['means', 2], ['conveyance', 1], ['railroads', 1], ['olden', 2], ['time', 3], ['will', 1], ['able', 2], ['pneumatic', 1], ['tubes', 1], ['which', 12], ['one', 7], ['travels', 1], ['rate', 1], ['miles', 1], ['an', 7], ['hour', 1], ['contemporaries', 1], ['prize', 1], ['telephone', 2], ['telephote', 2], ['more', 3], ['highly', 1], ['had', 1], ['forgotten', 1], ['telegraph', 1], ['singularly', 1], ['enough', 1], ['these', 8], ['transformations', 1], ['rest', 1], ['upon', 2], ['principles', 2], ['perfectly', 1], ['familiar', 2], ['remote', 2], ['ancestors', 1], ['disregarded', 1], ['heat', 3], ['instance', 1], ['ancient', 1], ['man', 3], ['himself', 2], ['electricity', 4], ['known', 2], ['3000', 1], ['years', 10], ['ago', 7], ['steam', 1], ['1100', 1], ['nay', 1], ['early', 1], ['ten', 2], ['centuries', 1], ['differences', 2], ['between', 1], ['several', 2], ['chemical', 1], ['physical', 1], ['forces', 3], ['depend', 1], ['mode', 3], ['vibration', 2], ['etheric', 1], ['particles', 1], ['specifically', 1], ['different', 1], ['last', 2], ['kinship', 1], ['discovered', 1], ['simply', 1], ['astounding', 1], ['500', 1], ['should', 3], ['still', 4], ['elapse', 1], ['before', 1], ['men', 3], ['analyze', 1], ['describe', 1], ['modes', 1], ['constit ...
# File assets/short.t1.txt : 200 lines, 1855 words, 772 distinct words
# [['the', 60], ['project', 5], ['gutenberg', 8], ['ebook', 5], ['bobbsey', 21], ['twins', 22], ['on', 15], ['blueberry', 9], ['island', 9], ['by', 5], ['laura', 4], ['lee', 4], ['hope', 4], ['this', 3], ['is', 5], ['for', 2], ['use', 2], ['of', 11], ['anyone', 1], ['anywhere', 1], ['at', 11], ['no', 2], ['cost', 1], ['and', 13], ['with', 2], ['almost', 1], ['restrictions', 1], ['whatsoever', 1], ['you', 4], ['may', 1], ['copy', 1], ['it', 6], ['give', 1], ['away', 1], ['or', 4], ['re', 1], ['under', 1], ['terms', 1], ['license', 1], ['included', 1], ['online', 2], ['www', 4], ['org', 1], ['title', 1], ['author', 2], ['release', 1], ['date', 1], ['january', 1], ['7', 1], ['2007', 1], ['20311', 8], ['language', 1], ['english', 1], ['character', 1], ['set', 1], ['encoding', 1], ['iso', 1], ['646', 1], ['us', 2], ['ascii', 1], ['start', 1], ['e', 1], ['text', 1], ['prepared', 1], ['marilynda', 1], ['fraser', 2], ['cunliffe', 1], ['j', 1], ['p', 1], ['w', 1], ['emmy', 1], ['distributed', 1], ['proofreading', 1], ['team', 1], ['http', 3], ['pgdp', 1], ['net', 3], ['c', 1], ['note', 1], ['also', 1], ['has', 1], ['an', 2], ['html', 1], ['version', 1], ['file', 1], ['which', 1], ['includes', 1], ['original', 1], ['illustrations', 1], ['see', 2], ['h', 5], ['htm', 2], ['zip', 2], ['dirs', 2], ['2', 2], ['0', 2], ['3', 2], ['1', 3], ['bunny', 9], ['brown', 9], ['series', 5], ['outdoor', 9], ['girls', 9], ['etc', 1], ['illustrated', 1], ['new', 2], ['york', 2], ['grosset', 3], ['dunlap', 3], ['publishers', 2], ['made', 1], ['in', 11], ['united', 1], ['states', 1], ['america', 1], ['books', 1], ['country', 1], ['seashore', 1], ['school', 1], ['snow', 1], ['lodge', 1], ['a', 14], ['houseboat', 1], ['meadow', 1], ['brook', 1], ['home', 4], ['great', 1], ['city', 2], ['his', 8], ['sister', 9], ['sue', 7], ['grandpa', 1], ['s', 6], ['farm', 1], ['playing', 1], ['circus', 1], ['aunt', 1], ['lu', 1], ['camp', 3], ['rest', 1], ['while', 2], ['big', 1], ['woods', 1], ['auto', 1], ['tour', 1], ['deepdale', 1], ['rainbow', 1], ['lake', 5], ['motor', 1], ['car', 1], ['winter', 1], ['florida', 1], ['ocean', 1], ['view', 1], ['pine', 1], ['copyright', 1], ['1917', 1], ['illustration', 1], ['freddie', 4], ['caught', 2], ['first', 1], ['fish', 1], ['frontispiece', 1], ['page', 2], ['123', 1], ['contents', 1], ['chapter', 2], ['i', 10], ['gypsies', 2], ['ii', 1], ['surprise', 1], ['13', 1], ['iii', 1], ['worried', 1], ['26', 1], ['iv', 1], ['goat', 1], ['36', 1], ['v', 1], ['bumpy', 1], ['ride', 1], ['47', 1], ['vi', 1], ['jolly', 1], ['news', 1], ['59', 1], ['vii', 1], ['where', 1], ['snap', 2], ['68', 1], ['viii', 1], ['off', 1], ['to', 9], ['78', 1], ['ix', 1], ['night', 1], ['scare', 1], ['90', 1], ['x', 1], ['go', 1], ['around', 1], ['bugs', 1], ['103', 1], ['xi', 1], ['boy', 2], ['112', 1], ['xii', 1], ['drifting', 1], ['boat', 2], ['126', 1], ['xiii', 1], ['cave', 1], ['137', 1], ['xiv', 1], ['helen', 1], ['visit', 1], ['147', 1], ['xv', 1], ['doll', 2], ['dress', 2], ['161', 1], ['xvi', 1], ['snoop', 1], ['missing', 1], ['170', 1], ['xvii', 1], ['179', 1], ['xviii', 1], ['flossie', 5], ['tangled', 1], ['191', 1], ['xix', 1], ['fall', 1], ['down', 1], ['202', 1], ['xx', 1], ['queer', 1], ['noise', 1], ['213', 1], ['xxi', 1], ['here', 1], ['comes', 1], ['221', 1], ['xxii', 1], ['happy', 1], ['days', 1], ['231', 1], ['oh', 1], ['dear', 1], ['wish', 1], ['we', 2], ['weren', 1], ['t', 4], ['going', 2], ['so', 4], ['do', 1], ['can', 1], ['stay', 2], ['out', 5], ['little', 2], ['longer', 2], ['why', 1], ['cried', 1], ['nan', 2], ['older', 1], ['two', 1], ['small', 1], ['who', 2], ['had', 1], ['spoken', 1], ['few', 1], ['minutes', 1], ['ago', 1], ['were', 2], ['hurry', 1], ['get', 1], ['yes', 1], ['they', 3], ['said', 4], ['hungry', 3], ['couldn', 1], ['wait', 1], ['what', 2], ['dinah', 2], ['was', 4], ['have', 2], ['supper', 1], ['bert', 1], ['how', 1], ['about', 1], ['that', 2], ['well', 2], ['m', 1], ['yet', 1], ['sitting', 1], ['beside', 1], ['being',  ...
# File assets/short.t2.txt : 200 lines, 752 words, 334 distinct words
# The cosine between the documents is  0.712533.
# The angle between the documents is  0.777694 radians or  45 degrees.

# %%
# time with refactored count_frequency function
# %timeit document_similarity('assets/t1.verne.txt','assets/t2.bobsey.txt')
# Out:
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# File assets/t1.verne.txt : 1057 lines, 8943 words, 2150 distinct words
# File assets/t2.bobsey.txt : 6667 lines, 49785 words, 3354 distinct words
# The cosine between the documents is  0.834843.
# The angle between the documents is  0.582949 radians or  33 degrees.
# 1.53 s ± 5.72 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)
